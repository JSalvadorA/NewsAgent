# %%
import os
import sys
import time
from datetime import datetime
from IPython.display import display, HTML

# Asegurarnos que la ruta del código está en el path
project_root = "C:/Jerson/SUNASS/2025/4_April/gem/scr1403"
code_dir = os.path.join(project_root, "codigo")
if code_dir not in sys.path:
    sys.path.append(code_dir)

# Importar utilidades específicas para notebooks
from codigo.notebook_utils import setup_environment

# Mostrar un mensaje de inicio
print("Iniciando ejecución del orquestador...")

# Función para ejecutar el orquestador
def ejecutar_orquestador(fecha, prompt="detallado", batch_size=3, pause_seconds=60):
    """
    Ejecuta el orquestador para una fecha específica.
    
    Args:
        fecha (str): Fecha en formato DDMMYYYY
        prompt (str): Tipo de prompt (simple, detallado, estructurado, anti-ruido)
        batch_size (int): Tamaño máximo del lote de imágenes (1-3). El sistema procesará adaptativamente.
        pause_seconds (int): Segundos de pausa entre lotes. Se aplica entre cada lote y reintentos.
    """
    # Configurar el entorno y logging antes de importar main
    logger = setup_environment(project_root)
    
    # Ahora importamos run_pipeline (después de configurar el logging)
    from main import run_pipeline
    
    # Configurar el archivo config.yaml
    config_file = os.path.join(project_root, "config.yaml")
    try:
        # Guardar configuración existente si existe
        config_backup = None
        if os.path.exists(config_file):
            with open(config_file, 'r', encoding='utf-8') as f:
                config_backup = f.read()
        
        # Escribir nueva configuración
        with open(config_file, 'w', encoding='utf-8') as f:
            f.write(f"""api:
  prompt_key: "{prompt}"
  batch_size: {batch_size}
  pause_seconds: {pause_seconds}
""")
        
        print(f"Configuración aplicada: prompt={prompt}, batch_size={batch_size}, pause={pause_seconds}s")
        
        # Ejecutar el orquestador
        print(f"Ejecutando orquestador para fecha: {fecha}")
        print("Esto puede tomar varios minutos. Por favor, espera...")
        
        start_time = datetime.now()
        run_pipeline(custom_date_str=fecha)
        end_time = datetime.now()
        
        duration = (end_time - start_time).total_seconds()
        print(f"✅ Procesamiento completado en {duration:.2f} segundos")
        
        # Restaurar configuración original si existía
        if config_backup:
            with open(config_file, 'w', encoding='utf-8') as f:
                f.write(config_backup)
    
    except Exception as e:
        print(f"Error ejecutando orquestador: {str(e)}")
        import traceback
        traceback.print_exc()

# Ejemplo de uso - descomenta la línea que necesites:
# ejecutar_orquestador("01042025")                      # Fecha básica con valores predeterminados
# ejecutar_orquestador("01042025", prompt="simple")     # Cambiando el prompt
# ejecutar_orquestador("01042025", batch_size=2)        # Procesando sólo 2 imágenes antes de pausar

print("Script cargado. Descomenta y ejecuta una de las líneas de ejemplo o usa la función 'ejecutar_orquestador'.")
# Out:
# Iniciando ejecución del orquestador...
# Script cargado. Descomenta y ejecuta una de las líneas de ejemplo o usa la función 'ejecutar_orquestador'.

# %% [markdown]
# ## Mejora en el procesamiento de imágenes
#
# El sistema ahora procesa imágenes de forma adaptativa con las siguientes mejoras:
#
# - **Procesamiento adaptativo**: Procesa imágenes en lotes secuenciales para evitar errores
# - **Reintento único**: Las imágenes que fallan en un primer procesamiento se reintentan una sola vez en el lote siguiente
# - **Continuidad garantizada**: Si una imagen falla después del reintento, el procesamiento continúa con las demás
# - **Configuración flexible**: Ajusta el tamaño del lote (1-3) según las características de tus imágenes
#
# Esto evita que queden imágenes sin procesar por problemas de capacidad en la API.

# %%
# Ejemplo de ejecución:
# ejecutar_orquestador("09042025")

# %% [markdown]
# ## Panel de control para ejecución fácil
#
# Para facilitar aún más el uso de esta herramienta a personas no familiarizadas con Python, puedes utilizar el siguiente panel interactivo:

# %%
#Descomenta y ejecuta esto para usar el panel interactivo
import ipywidgets as widgets
from IPython.display import display, clear_output

# Crear widgets para la entrada de datos
fecha_input = widgets.Text(value='14032025', description='Fecha (DDMMYYYY):')
prompt_dropdown = widgets.Dropdown(
    options=['simple', 'detallado', 'estructurado', 'anti-ruido'],
    value='detallado',
    description='Tipo de prompt:'
)
batch_slider = widgets.IntSlider(value=3, min=1, max=10, description='Batch size:')
pause_slider = widgets.IntSlider(value=60, min=10, max=300, description='Pausa (seg):')

# Función para manejar el botón de ejecución
def on_ejecutar_button_clicked(b):
    with output:
        clear_output()
        ejecutar_orquestador(
            fecha_input.value,
            prompt=prompt_dropdown.value,
            batch_size=batch_slider.value,
            pause_seconds=pause_slider.value
        )

# Crear botón de ejecución
ejecutar_button = widgets.Button(description='Ejecutar Orquestador')
ejecutar_button.on_click(on_ejecutar_button_clicked)

# Crear área de salida
output = widgets.Output()

# Mostrar interfaz
display(widgets.VBox([
    widgets.HBox([fecha_input, prompt_dropdown]),
    widgets.HBox([batch_slider, pause_slider]),
    ejecutar_button,
    output
]))
# Out:
# VBox(children=(HBox(children=(Text(value='14032025', description='Fecha (DDMMYYYY):'), Dropdown(description='T…
# 2025-04-10 18:21:03,379 - lib.image_processor - INFO - Imagen 4 guardada como 'img_4_8d7715e7_14032025.jpg' en C:\Jerson\SUNASS\2025\4_April\gem\scr1403\input\Images\downloads\14032025 (117350 bytes)
# 2025-04-10 18:21:03,383 - lib.image_processor - INFO - Imagen 3 guardada como 'img_3_7294265b_14032025.jpg' en C:\Jerson\SUNASS\2025\4_April\gem\scr1403\input\Images\downloads\14032025 (174020 bytes)
# 2025-04-10 18:21:03,537 - lib.image_processor - INFO - Imagen 1 guardada como 'img_1_a536c3b1_14032025.jpg' en C:\Jerson\SUNASS\2025\4_April\gem\scr1403\input\Images\downloads\14032025 (331752 bytes)
# 2025-04-10 18:22:18,483 - lib.facebook_processor - INFO - Procesando URL de Facebook (1): https://www.facebook.com/story.php?story_fbid=pfbid02YqHZnkfqnKMLnK3D4Jy5aNmEgh2xD8KNQLhcu9KYXY8TRf5Rh85hqCH1xgw4Cg9Ql&id=100086343859023&sfnsn=wa&mibextid=VhDh1V&_rdr
# 2025-04-10 18:22:18,487 - lib.facebook_processor - INFO - Procesando URL de Facebook (2): https://www.facebook.com/story.php?story_fbid=122152370354541573&id=61566247194910&rdid=eqZcPKjSj3vqDB0T
# 2025-04-10 18:22:18,488 - lib.facebook_processor - INFO - Procesando URL de Facebook (3): https://www.facebook.com/story.php?story_fbid=1302583471230687&id=100044371395172&rdid=I7fzNvf1EHJT9KAR
# 2025-04-10 18:22:18,489 - lib.facebook_processor - INFO - Procesando URL de Facebook (4): https://www.facebook.com/story.php?story_fbid=1302583471230687&id=100044371395172&rdid=I7fzNvf1EHJT9KAR
# 2025-04-10 18:22:18,493 - lib.facebook_processor - INFO - Procesando URL de Facebook (5): https://www.facebook.com/story.php?story_fbid=1715103185946131&id=100023393993678&rdid=1VTlmy9xx0dZEIyQ
# 2025-04-10 18:22:33,433 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-4.pdf
# 2025-04-10 18:22:33,886 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-5.pdf
# 2025-04-10 18:22:34,044 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-1.pdf
# 2025-04-10 18:22:35,315 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-3.pdf
# 2025-04-10 18:22:35,339 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-2.pdf
# 2025-04-10 18:22:37,573 - lib.facebook_processor - INFO - Procesando URL de Facebook (6): https://www.facebook.com/story.php?story_fbid=1208665124597009&id=100063605992702&rdid=Vs9J5ByfNMV4Zj2V
# 2025-04-10 18:22:37,793 - lib.facebook_processor - INFO - Procesando URL de Facebook (7): https://www.facebook.com/photo/?fbid=971223294993631&set=a.118074166975219
# 2025-04-10 18:22:37,862 - lib.facebook_processor - INFO - Procesando URL de Facebook (8): https://www.facebook.com/photo/?fbid=971223294993631&set=a.118074166975219
# 2025-04-10 18:22:40,402 - lib.facebook_processor - INFO - Procesando URL de Facebook (9): https://www.facebook.com/photo/?fbid=971223294993631&set=a.118074166975219
# 2025-04-10 18:22:40,696 - lib.facebook_processor - INFO - Procesando URL de Facebook (10): https://www.facebook.com/photo/?fbid=1233267452132887&set=a.502725681853738
# 2025-04-10 18:22:52,426 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-6.pdf
# 2025-04-10 18:22:52,847 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-7.pdf
# 2025-04-10 18:22:55,352 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-10.pdf
# 2025-04-10 18:22:55,354 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-9.pdf
# 2025-04-10 18:22:55,745 - lib.facebook_processor - INFO - Procesando URL de Facebook (11): https://www.facebook.com/photo/?fbid=1184100673715672&set=a.502401198552293
# 2025-04-10 18:22:57,835 - lib.facebook_processor - INFO - Procesando URL de Facebook (12): https://www.facebook.com/photo/?fbid=1305708994330935&set=a.613217726913402
# 2025-04-10 18:23:00,428 - lib.facebook_processor - INFO - Procesando URL de Facebook (13): https://www.facebook.com/photo/?fbid=1305708994330935&set=a.613217726913402
# 2025-04-10 18:23:00,461 - lib.facebook_processor - INFO - Procesando URL de Facebook (14): https://www.facebook.com/photo/?fbid=621285140773431&set=a.111597801742170
# 2025-04-10 18:23:00,884 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-8.pdf
# 2025-04-10 18:23:05,353 - lib.facebook_processor - INFO - Procesando URL de Facebook (15): https://www.facebook.com/photo/?fbid=122205267428171475&set=a.122112503246171475
# 2025-04-10 18:23:11,146 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-11.pdf
# 2025-04-10 18:23:13,025 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-12.pdf
# 2025-04-10 18:23:14,761 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-13.pdf
# 2025-04-10 18:23:15,515 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-14.pdf
# 2025-04-10 18:23:16,739 - lib.facebook_processor - INFO - Procesando URL de Facebook (16): https://www.facebook.com/photo/?fbid=647635901343345&set=a.134210922685848
# 2025-04-10 18:23:19,005 - lib.facebook_processor - INFO - Procesando URL de Facebook (17): https://www.facebook.com/photo/?fbid=647635901343345&set=a.134210922685848
# 2025-04-10 18:23:19,563 - lib.facebook_processor - INFO - Procesando URL de Facebook (18): https://www.facebook.com/photo/?fbid=1049183370562726&set=a.322443046570099
# 2025-04-10 18:23:19,791 - lib.facebook_processor - INFO - Procesando URL de Facebook (19): https://www.facebook.com/photo/?fbid=122123721008693859&set=a.122108624150693859
# 2025-04-10 18:23:21,185 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-15.pdf
# 2025-04-10 18:23:26,039 - lib.facebook_processor - INFO - Procesando URL de Facebook (20): https://www.facebook.com/photo/?fbid=612146391691504&set=a.101152569457558
# 2025-04-10 18:23:31,316 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-16.pdf
# 2025-04-10 18:23:36,215 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-17.pdf
# 2025-04-10 18:23:39,139 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-18.pdf
# 2025-04-10 18:23:40,529 - lib.facebook_processor - INFO - Procesando URL de Facebook (21): https://www.facebook.com/photo/?fbid=122123721008693859&set=a.122108624150693859
# 2025-04-10 18:23:41,427 - lib.facebook_processor - INFO - Procesando URL de Facebook (22): https://www.facebook.com/photo/?fbid=612146391691504&set=a.101152569457558
# 2025-04-10 18:23:43,931 - lib.facebook_processor - INFO - Procesando URL de Facebook (23): https://www.facebook.com/share/p/16Ao1xQ4N4/
# 2025-04-10 18:23:46,181 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-20.pdf
# 2025-04-10 18:23:52,680 - lib.facebook_processor - INFO - Procesando URL de Facebook (24): https://www.facebook.com/share/p/1HxWqW6yae/
# 2025-04-10 18:23:58,708 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-21.pdf
# 2025-04-10 18:23:59,408 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-22.pdf
# 2025-04-10 18:24:02,215 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-19.pdf
# 2025-04-10 18:24:02,797 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-23.pdf
# 2025-04-10 18:24:02,909 - lib.facebook_processor - INFO - Procesando URL de Facebook (25): https://www.facebook.com/share/p/1BfQaZKmDs/
# 2025-04-10 18:24:03,556 - lib.facebook_processor - INFO - Procesando URL de Facebook (26): https://www.facebook.com/share/p/1HcxtjtR8H/
# 2025-04-10 18:24:07,450 - lib.facebook_processor - INFO - Procesando URL de Facebook (27): https://www.facebook.com/share/p/18gLYzVC4U/
# 2025-04-10 18:24:07,567 - lib.facebook_processor - INFO - Procesando URL de Facebook (28): https://www.facebook.com/share/v/16GcCs3Sjh/
# 2025-04-10 18:24:12,422 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-24.pdf
# 2025-04-10 18:24:19,625 - lib.facebook_processor - INFO - Procesando URL de Facebook (29): https://www.facebook.com/100063563691565/posts/1229189359209842/
# 2025-04-10 18:24:20,236 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-26.pdf
# 2025-04-10 18:24:20,641 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-25.pdf
# 2025-04-10 18:24:25,485 - lib.facebook_processor - INFO - Procesando URL de Facebook (30): https://www.facebook.com/100063579174279/posts/1224069649722329/
# 2025-04-10 18:24:25,700 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-27.pdf
# 2025-04-10 18:24:26,253 - lib.facebook_processor - INFO - Procesando URL de Facebook (31): https://www.facebook.com/watch/?v=1015675083782593
# 2025-04-10 18:24:30,303 - lib.facebook_processor - INFO - Procesando URL de Facebook (32): https://www.facebook.com/share/1AHHK9bqUw/
# 2025-04-10 18:24:32,441 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-28.pdf
# 2025-04-10 18:24:39,096 - lib.facebook_processor - INFO - Procesando URL de Facebook (33): https://www.facebook.com/share/p/15uhgbqBc2/
# 2025-04-10 18:24:39,138 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-29.pdf
# 2025-04-10 18:24:43,505 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-30.pdf
# 2025-04-10 18:24:44,449 - lib.facebook_processor - INFO - Procesando URL de Facebook (34): https://www.facebook.com/share/p/15uhgbqBc2/
# 2025-04-10 18:24:48,240 - lib.facebook_processor - INFO - Procesando URL de Facebook (35): https://www.facebook.com/share/p/14x2NGKNBnM/
# 2025-04-10 18:24:50,177 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-32.pdf
# 2025-04-10 18:24:55,412 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-33.pdf
# 2025-04-10 18:24:56,051 - lib.facebook_processor - INFO - Procesando URL de Facebook (36): https://www.facebook.com/photo?fbid=666463449225250&set=pcb.666463792558549
# 2025-04-10 18:25:06,987 - lib.facebook_processor - INFO - Procesando URL de Facebook (37): https://www.facebook.com/permalink.php?story_fbid=pfbid02nK1fuT4d3tmYqCABhCE3ZpzFEEaC3k5UWvVx5YHafhfm95e3iM6Dxepq96DH9Vo9l&id=100065273659654
# 2025-04-10 18:25:09,313 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-34.pdf
# 2025-04-10 18:25:12,641 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-35.pdf
# 2025-04-10 18:25:16,100 - lib.facebook_processor - INFO - Procesando URL de Facebook (38): https://www.facebook.com/permalink.php?story_fbid=pfbid02nK1fuT4d3tmYqCABhCE3ZpzFEEaC3k5UWvVx5YHafhfm95e3iM6Dxepq96DH9Vo9l&id=100065273659654
# 2025-04-10 18:25:16,683 - lib.facebook_processor - INFO - Procesando URL de Facebook (39): https://www.facebook.com/permalink.php?story_fbid=pfbid0sKx2bpDVVxqgAwD1ie1nQjcmVSddvdXvawS4X48db4yjY1dMRm6JgaANfrcGtbZkl&id=100064089484737
# 2025-04-10 18:25:17,497 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-36.pdf
# 2025-04-10 18:25:24,369 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-37.pdf
# 2025-04-10 18:25:24,449 - lib.facebook_processor - INFO - Procesando URL de Facebook (40): https://www.facebook.com/permalink.php?story_fbid=pfbid0nJMj5TS8v2nxEykc9dXwFMpzARgXjdjff5W7oTqeBQb8HRMgps8pujw1QtoRrphhl&id=100072108931277
# 2025-04-10 18:25:28,464 - lib.facebook_processor - INFO - Procesando URL de Facebook (41): https://www.facebook.com/permalink.php?story_fbid=pfbid02XNebYvPc8wCdjrFD1GAT9pHYD1hpQPxPordzAJGmvscYgT9NYpKbS2PL9y9XHNftl&id=100062993063417
# 2025-04-10 18:25:32,553 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-31.pdf
# 2025-04-10 18:25:33,777 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-39.pdf
# 2025-04-10 18:25:34,927 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-38.pdf
# 2025-04-10 18:25:39,424 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-40.pdf
# 2025-04-10 18:25:39,457 - lib.facebook_processor - INFO - Procesando URL de Facebook (42): https://www.facebook.com/permalink.php?story_fbid=pfbid02K7agg7fugZKVWQ7c5egzX6SiNTsYH1qoaZXEQxJ2SYd7pEPfPhQBvnE1ubXumpTZl&id=100063616446639
# 2025-04-10 18:25:39,551 - lib.facebook_processor - INFO - Procesando URL de Facebook (43): https://www.facebook.com/permalink.php?story_fbid=pfbid0YZ8AbysMpEsCc1UoLi86FCxrvnMeFN5XsLkCPLKRShCBijqyHJshp1gVGCj97oYYl&id=61559613183648
# 2025-04-10 18:25:40,617 - lib.facebook_processor - INFO - Procesando URL de Facebook (44): https://www.facebook.com/arequipametropolitana/posts/pfbid033TAqbsFJEUwf7GoAkRFLrpjk9zjh3nAccT2m8WYQc9nR7NqytKyXUqmFeu9CBL9yl
# 2025-04-10 18:25:43,596 - lib.facebook_processor - INFO - Procesando URL de Facebook (45): https://www.facebook.com/arequipametropolitana/posts/pfbid033TAqbsFJEUwf7GoAkRFLrpjk9zjh3nAccT2m8WYQc9nR7NqytKyXUqmFeu9CBL9yl
# 2025-04-10 18:25:48,559 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-41.pdf
# 2025-04-10 18:25:53,099 - lib.facebook_processor - INFO - Procesando URL de Facebook (46): https://www.facebook.com/permalink.php?story_fbid=pfbid02oU4rwtUF5AVcMPRMZXT9nXpLVi6qUSpddH2FtUvKq4aLF14LXxc1MJBZ1vM6RJsEl&id=61573830030264
# 2025-04-10 18:25:57,616 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-42.pdf
# 2025-04-10 18:25:58,352 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-43.pdf
# 2025-04-10 18:25:59,971 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-44.pdf
# 2025-04-10 18:26:01,841 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-45.pdf
# 2025-04-10 18:26:03,144 - lib.facebook_processor - INFO - Procesando URL de Facebook (47): https://www.facebook.com/permalink.php?story_fbid=pfbid0tscNSyDMrKwBCC1WQyBaQz5WNnuxHvq5gijneun7Ck9tu6cSuSZoPvKZFu7oSRfgl&id=100083430338466
# 2025-04-10 18:26:03,552 - lib.facebook_processor - INFO - Procesando URL de Facebook (48): https://www.facebook.com/Losprotagonistasdelanoticia/posts/pfbid02WAeMjmxyDHwKgqh3nBW7nkRcqSWFPNAAHq5CB6QSTyjPWK7Ea818NexG3fV6wSt3l
# 2025-04-10 18:26:04,358 - lib.facebook_processor - INFO - Procesando URL de Facebook (49): https://www.facebook.com/polemicaynoticiasaqpoficial/posts/pfbid0ZiBLDBdszjC4mZEJHnbBSXmzDWqnTNQz2ApRuLAVh9VDM417cAMq9r5urjscMaGrl
# 2025-04-10 18:26:05,599 - lib.facebook_processor - INFO - Procesando URL de Facebook (50): https://www.facebook.com/polemicaynoticiasaqpoficial/posts/pfbid0ZiBLDBdszjC4mZEJHnbBSXmzDWqnTNQz2ApRuLAVh9VDM417cAMq9r5urjscMaGrl
# 2025-04-10 18:26:18,822 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-47.pdf
# 2025-04-10 18:26:20,279 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-48.pdf
# 2025-04-10 18:26:23,754 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-49.pdf
# 2025-04-10 18:26:24,155 - lib.facebook_processor - INFO - Procesando URL de Facebook (51): https://www.facebook.com/RadioLasVegasPortaldeMollendo/posts/pfbid0uht5eYokC9Zvu2VFQU5FfrSb75Nhnm94bWpSsu9mFqsJg56TPJix32MxaBpgPrxTl
# 2025-04-10 18:26:25,357 - lib.facebook_processor - INFO - Procesando URL de Facebook (52): https://www.facebook.com/RadioLasVegasPortaldeMollendo/posts/pfbid0uht5eYokC9Zvu2VFQU5FfrSb75Nhnm94bWpSsu9mFqsJg56TPJix32MxaBpgPrxTl
# 2025-04-10 18:26:25,577 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-50.pdf
# 2025-04-10 18:26:27,834 - lib.facebook_processor - INFO - Procesando URL de Facebook (53): https://www.facebook.com/informateperuanohoy/posts/pfbid02niPBppaPir9nfCdvKXn9NzhjKokcwtvRSuuro6MqJBvdq2coxD5RwCGB3otEmArHl
# 2025-04-10 18:26:30,516 - lib.facebook_processor - INFO - Procesando URL de Facebook (54): https://www.facebook.com/Arequipa.pe/posts/pfbid02SH1uRq3VMtT9C8joLcwudoVUe39Gt4Hw7u72Wqh4VAjUQkxfXzxHMgCnnjgTuG3Ml
# 2025-04-10 18:26:40,364 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-51.pdf
# 2025-04-10 18:26:41,547 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-52.pdf
# 2025-04-10 18:26:43,179 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-53.pdf
# 2025-04-10 18:26:43,740 - lib.facebook_processor - INFO - Procesando URL de Facebook (55): https://www.facebook.com/permalink.php?story_fbid=pfbid02FinUrue2m3q9qB5PENKYThjD24abSWa1SAMw2AKbigULRyEM3HREnjUcr3HuhWHwl&id=61572359463553
# 2025-04-10 18:26:46,337 - lib.facebook_processor - INFO - Procesando URL de Facebook (56): https://www.facebook.com/share/p/1BzoKcA2vn/
# 2025-04-10 18:26:47,710 - lib.facebook_processor - INFO - Procesando URL de Facebook (57): https://www.facebook.com/share/p/1BzoKcA2vn/
# 2025-04-10 18:26:47,896 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-54.pdf
# 2025-04-10 18:26:53,105 - lib.facebook_processor - INFO - Procesando URL de Facebook (58): https://www.facebook.com/share/p/15VTXnEzmT/
# 2025-04-10 18:26:53,804 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-46.pdf
# 2025-04-10 18:26:57,797 - lib.facebook_processor - INFO - Procesando URL de Facebook (59): https://www.facebook.com/share/p/1GjC64uVzL/
# 2025-04-10 18:26:59,196 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-55.pdf
# 2025-04-10 18:27:03,960 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-56.pdf
# 2025-04-10 18:27:04,225 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-57.pdf
# 2025-04-10 18:27:07,357 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-58.pdf
# 2025-04-10 18:27:07,418 - lib.facebook_processor - INFO - Procesando URL de Facebook (60): https://www.facebook.com/share/p/1H6owrjkTP/
# 2025-04-10 18:27:09,059 - lib.facebook_processor - INFO - Procesando URL de Facebook (61): https://www.facebook.com/photo/?fbid=665633532641575&set=pcb.665633929308202
# 2025-04-10 18:27:09,343 - lib.facebook_processor - INFO - Procesando URL de Facebook (62): https://www.facebook.com/share/p/15EtbVxxbS/
# 2025-04-10 18:27:11,727 - lib.facebook_processor - INFO - Procesando URL de Facebook (63): https://www.facebook.com/share/p/1BbUziDa1J/
# 2025-04-10 18:27:17,720 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-59.pdf
# 2025-04-10 18:27:23,000 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-60.pdf
# 2025-04-10 18:27:23,813 - lib.facebook_processor - INFO - Procesando URL de Facebook (64): https://www.facebook.com/share/p/1BbUziDa1J/
# 2025-04-10 18:27:24,894 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-61.pdf
# 2025-04-10 18:27:28,211 - lib.facebook_processor - INFO - Procesando URL de Facebook (65): https://www.facebook.com/share/p/166gqtrsYg/
# 2025-04-10 18:27:29,544 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-62.pdf
# 2025-04-10 18:27:31,292 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-63.pdf
# 2025-04-10 18:27:32,345 - lib.facebook_processor - INFO - Procesando URL de Facebook (66): https://www.facebook.com/share/p/12KRF7zpYj9/
# 2025-04-10 18:27:36,721 - lib.facebook_processor - INFO - Procesando URL de Facebook (67): https://www.facebook.com/share/p/1ABV3uWCDB/
# 2025-04-10 18:27:41,443 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-64.pdf
# 2025-04-10 18:27:44,506 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-65.pdf
# 2025-04-10 18:27:48,395 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-66.pdf
# 2025-04-10 18:27:51,128 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\14032025\14032025-67.pdf
