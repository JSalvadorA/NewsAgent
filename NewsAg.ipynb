# %%
import os
import sys
import time
from datetime import datetime
from IPython.display import display, HTML

# Asegurarnos que la ruta del código está en el path
project_root = "C:/Jerson/SUNASS/2025/4_April/gem/scr1403"
code_dir = os.path.join(project_root, "codigo")
if code_dir not in sys.path:
    sys.path.append(code_dir)

# Importar utilidades específicas para notebooks
from codigo.notebook_utils import setup_environment

# Mostrar un mensaje de inicio
print("Iniciando ejecución del orquestador...")

# Función para ejecutar el orquestador
def ejecutar_orquestador(fecha, prompt="detallado", batch_size=3, pause_seconds=60):
    """
    Ejecuta el orquestador para una fecha específica.
    
    Args:
        fecha (str): Fecha en formato DDMMYYYY
        prompt (str): Tipo de prompt (simple, detallado, estructurado, anti-ruido)
        batch_size (int): Tamaño máximo del lote de imágenes (1-3). El sistema procesará adaptativamente.
        pause_seconds (int): Segundos de pausa entre lotes. Se aplica entre cada lote y reintentos.
    """
    # Configurar el entorno y logging antes de importar main
    logger = setup_environment(project_root)
    
    # Ahora importamos run_pipeline (después de configurar el logging)
    from main import run_pipeline
    
    # Configurar el archivo config.yaml
    config_file = os.path.join(project_root, "config.yaml")
    try:
        # Guardar configuración existente si existe
        config_backup = None
        if os.path.exists(config_file):
            with open(config_file, 'r', encoding='utf-8') as f:
                config_backup = f.read()
        
        # Escribir nueva configuración
        with open(config_file, 'w', encoding='utf-8') as f:
            f.write(f"""api:
  prompt_key: "{prompt}"
  batch_size: {batch_size}
  pause_seconds: {pause_seconds}
""")
        
        print(f"Configuración aplicada: prompt={prompt}, batch_size={batch_size}, pause={pause_seconds}s")
        
        # Ejecutar el orquestador
        print(f"Ejecutando orquestador para fecha: {fecha}")
        print("Esto puede tomar varios minutos. Por favor, espera...")
        
        start_time = datetime.now()
        run_pipeline(custom_date_str=fecha)
        end_time = datetime.now()
        
        duration = (end_time - start_time).total_seconds()
        print(f"✅ Procesamiento completado en {duration:.2f} segundos")
        
        # Restaurar configuración original si existía
        if config_backup:
            with open(config_file, 'w', encoding='utf-8') as f:
                f.write(config_backup)
    
    except Exception as e:
        print(f"Error ejecutando orquestador: {str(e)}")
        import traceback
        traceback.print_exc()

# Ejemplo de uso - descomenta la línea que necesites:
# ejecutar_orquestador("01042025")                      # Fecha básica con valores predeterminados
# ejecutar_orquestador("01042025", prompt="simple")     # Cambiando el prompt
# ejecutar_orquestador("01042025", batch_size=2)        # Procesando sólo 2 imágenes antes de pausar

print("Script cargado. Descomenta y ejecuta una de las líneas de ejemplo o usa la función 'ejecutar_orquestador'.")
# Out:
# Iniciando ejecución del orquestador...
# Script cargado. Descomenta y ejecuta una de las líneas de ejemplo o usa la función 'ejecutar_orquestador'.

# %% [markdown]
# ## Mejora en el procesamiento de imágenes
#
# El sistema ahora procesa imágenes de forma adaptativa con las siguientes mejoras:
#
# - **Procesamiento adaptativo**: Procesa imágenes en lotes secuenciales para evitar errores
# - **Reintento único**: Las imágenes que fallan en un primer procesamiento se reintentan una sola vez en el lote siguiente
# - **Continuidad garantizada**: Si una imagen falla después del reintento, el procesamiento continúa con las demás
# - **Configuración flexible**: Ajusta el tamaño del lote (1-3) según las características de tus imágenes
#
# Esto evita que queden imágenes sin procesar por problemas de capacidad en la API.

# %%
# Ejemplo de ejecución:
# ejecutar_orquestador("09042025")

# %% [markdown]
# ## Panel de control para ejecución fácil
#
# Para facilitar aún más el uso de esta herramienta a personas no familiarizadas con Python, puedes utilizar el siguiente panel interactivo:

# %%
#Descomenta y ejecuta esto para usar el panel interactivo
import ipywidgets as widgets
from IPython.display import display, clear_output

# Crear widgets para la entrada de datos
fecha_input = widgets.Text(value='09042025', description='Fecha (DDMMYYYY):')
prompt_dropdown = widgets.Dropdown(
    options=['simple', 'detallado', 'estructurado', 'anti-ruido'],
    value='detallado',
    description='Tipo de prompt:'
)
batch_slider = widgets.IntSlider(value=3, min=1, max=10, description='Batch size:')
pause_slider = widgets.IntSlider(value=60, min=10, max=300, description='Pausa (seg):')

# Función para manejar el botón de ejecución
def on_ejecutar_button_clicked(b):
    with output:
        clear_output()
        ejecutar_orquestador(
            fecha_input.value,
            prompt=prompt_dropdown.value,
            batch_size=batch_slider.value,
            pause_seconds=pause_slider.value
        )

# Crear botón de ejecución
ejecutar_button = widgets.Button(description='Ejecutar Orquestador')
ejecutar_button.on_click(on_ejecutar_button_clicked)

# Crear área de salida
output = widgets.Output()

# Mostrar interfaz
display(widgets.VBox([
    widgets.HBox([fecha_input, prompt_dropdown]),
    widgets.HBox([batch_slider, pause_slider]),
    ejecutar_button,
    output
]))
# Out:
# VBox(children=(HBox(children=(Text(value='09042025', description='Fecha (DDMMYYYY):'), Dropdown(description='T…
# 2025-04-21 15:24:41,779 - lib.image_processor - INFO - Imagen 2 guardada como 'img_2_2e53b598_09042025.jpg' en C:\Jerson\SUNASS\2025\4_April\gem\scr1403\input\Images\downloads\09042025 (291939 bytes)
# 2025-04-21 15:24:43,312 - lib.image_processor - INFO - Imagen 1 guardada como 'img_1_6bb6f370_09042025.jpg' en C:\Jerson\SUNASS\2025\4_April\gem\scr1403\input\Images\downloads\09042025 (1191014 bytes)
# 2025-04-21 15:24:44,361 - urllib3.connectionpool - WARNING - Retrying (Retry(total=2, connect=3, read=3, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)'))': /actualidad/seda-huanuco-detecta-manipulacion-y-alteracion-de-medidores-de-agua/
# 2025-04-21 15:24:44,361 - urllib3.connectionpool - WARNING - Retrying (Retry(total=2, connect=3, read=3, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)'))': /politica/inician-estudios-para-delimitar-el-humedal-de-huachog-y-destrabar-proyecto-de-la-ptar/
# 2025-04-21 15:24:45,527 - urllib3.connectionpool - WARNING - Retrying (Retry(total=1, connect=3, read=3, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)'))': /politica/inician-estudios-para-delimitar-el-humedal-de-huachog-y-destrabar-proyecto-de-la-ptar/
# 2025-04-21 15:24:45,538 - urllib3.connectionpool - WARNING - Retrying (Retry(total=1, connect=3, read=3, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)'))': /actualidad/seda-huanuco-detecta-manipulacion-y-alteracion-de-medidores-de-agua/
# 2025-04-21 15:24:47,665 - urllib3.connectionpool - WARNING - Retrying (Retry(total=0, connect=3, read=3, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)'))': /actualidad/seda-huanuco-detecta-manipulacion-y-alteracion-de-medidores-de-agua/
# 2025-04-21 15:24:47,707 - urllib3.connectionpool - WARNING - Retrying (Retry(total=0, connect=3, read=3, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)'))': /politica/inician-estudios-para-delimitar-el-humedal-de-huachog-y-destrabar-proyecto-de-la-ptar/
# 2025-04-21 15:24:47,936 - lib.html_scraper - WARNING - Error de red scrapeando https://tudiariohuanuco.pe/actualidad/seda-huanuco-detecta-manipulacion-y-alteracion-de-medidores-de-agua/ (intento 1/4): HTTPSConnectionPool(host='tudiariohuanuco.pe', port=443): Max retries exceeded with url: /actualidad/seda-huanuco-detecta-manipulacion-y-alteracion-de-medidores-de-agua/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)')))
# 2025-04-21 15:24:47,936 - lib.html_scraper - WARNING - Error de red scrapeando https://tudiariohuanuco.pe/politica/inician-estudios-para-delimitar-el-humedal-de-huachog-y-destrabar-proyecto-de-la-ptar/ (intento 1/4): HTTPSConnectionPool(host='tudiariohuanuco.pe', port=443): Max retries exceeded with url: /politica/inician-estudios-para-delimitar-el-humedal-de-huachog-y-destrabar-proyecto-de-la-ptar/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)')))
# 2025-04-21 15:24:47,937 - lib.html_scraper - INFO - Reintentando https://tudiariohuanuco.pe/actualidad/seda-huanuco-detecta-manipulacion-y-alteracion-de-medidores-de-agua/ en 2 segundos... (intento 2/4)
# 2025-04-21 15:24:47,938 - lib.html_scraper - INFO - Reintentando https://tudiariohuanuco.pe/politica/inician-estudios-para-delimitar-el-humedal-de-huachog-y-destrabar-proyecto-de-la-ptar/ en 2 segundos... (intento 2/4)
# 2025-04-21 15:24:50,253 - urllib3.connectionpool - WARNING - Retrying (Retry(total=2, connect=3, read=3, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)'))': /actualidad/seda-huanuco-detecta-manipulacion-y-alteracion-de-medidores-de-agua/
# 2025-04-21 15:24:50,253 - urllib3.connectionpool - WARNING - Retrying (Retry(total=2, connect=3, read=3, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)'))': /politica/inician-estudios-para-delimitar-el-humedal-de-huachog-y-destrabar-proyecto-de-la-ptar/
# 2025-04-21 15:24:51,505 - urllib3.connectionpool - WARNING - Retrying (Retry(total=1, connect=3, read=3, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)'))': /actualidad/seda-huanuco-detecta-manipulacion-y-alteracion-de-medidores-de-agua/
# 2025-04-21 15:24:51,516 - urllib3.connectionpool - WARNING - Retrying (Retry(total=1, connect=3, read=3, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)'))': /politica/inician-estudios-para-delimitar-el-humedal-de-huachog-y-destrabar-proyecto-de-la-ptar/
# 2025-04-21 15:24:53,688 - urllib3.connectionpool - WARNING - Retrying (Retry(total=0, connect=3, read=3, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)'))': /actualidad/seda-huanuco-detecta-manipulacion-y-alteracion-de-medidores-de-agua/
# 2025-04-21 15:24:53,708 - urllib3.connectionpool - WARNING - Retrying (Retry(total=0, connect=3, read=3, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)'))': /politica/inician-estudios-para-delimitar-el-humedal-de-huachog-y-destrabar-proyecto-de-la-ptar/
# 2025-04-21 15:24:53,830 - lib.html_scraper - WARNING - Error de red scrapeando https://tudiariohuanuco.pe/actualidad/seda-huanuco-detecta-manipulacion-y-alteracion-de-medidores-de-agua/ (intento 2/4): HTTPSConnectionPool(host='tudiariohuanuco.pe', port=443): Max retries exceeded with url: /actualidad/seda-huanuco-detecta-manipulacion-y-alteracion-de-medidores-de-agua/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)')))
# 2025-04-21 15:24:53,832 - lib.html_scraper - INFO - Reintentando https://tudiariohuanuco.pe/actualidad/seda-huanuco-detecta-manipulacion-y-alteracion-de-medidores-de-agua/ en 5 segundos... (intento 3/4)
# 2025-04-21 15:24:53,833 - lib.html_scraper - WARNING - Error de red scrapeando https://tudiariohuanuco.pe/politica/inician-estudios-para-delimitar-el-humedal-de-huachog-y-destrabar-proyecto-de-la-ptar/ (intento 2/4): HTTPSConnectionPool(host='tudiariohuanuco.pe', port=443): Max retries exceeded with url: /politica/inician-estudios-para-delimitar-el-humedal-de-huachog-y-destrabar-proyecto-de-la-ptar/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)')))
# 2025-04-21 15:24:53,833 - lib.html_scraper - INFO - Reintentando https://tudiariohuanuco.pe/politica/inician-estudios-para-delimitar-el-humedal-de-huachog-y-destrabar-proyecto-de-la-ptar/ en 5 segundos... (intento 3/4)
# 2025-04-21 15:24:59,197 - urllib3.connectionpool - WARNING - Retrying (Retry(total=2, connect=3, read=3, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)'))': /actualidad/seda-huanuco-detecta-manipulacion-y-alteracion-de-medidores-de-agua/
# 2025-04-21 15:24:59,197 - urllib3.connectionpool - WARNING - Retrying (Retry(total=2, connect=3, read=3, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)'))': /politica/inician-estudios-para-delimitar-el-humedal-de-huachog-y-destrabar-proyecto-de-la-ptar/
# 2025-04-21 15:25:00,475 - urllib3.connectionpool - WARNING - Retrying (Retry(total=1, connect=3, read=3, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)'))': /politica/inician-estudios-para-delimitar-el-humedal-de-huachog-y-destrabar-proyecto-de-la-ptar/
# 2025-04-21 15:25:00,523 - urllib3.connectionpool - WARNING - Retrying (Retry(total=1, connect=3, read=3, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)'))': /actualidad/seda-huanuco-detecta-manipulacion-y-alteracion-de-medidores-de-agua/
# 2025-04-21 15:25:02,741 - urllib3.connectionpool - WARNING - Retrying (Retry(total=0, connect=3, read=3, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)'))': /actualidad/seda-huanuco-detecta-manipulacion-y-alteracion-de-medidores-de-agua/
# 2025-04-21 15:25:02,758 - urllib3.connectionpool - WARNING - Retrying (Retry(total=0, connect=3, read=3, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)'))': /politica/inician-estudios-para-delimitar-el-humedal-de-huachog-y-destrabar-proyecto-de-la-ptar/
# 2025-04-21 15:25:02,946 - lib.html_scraper - WARNING - Error de red scrapeando https://tudiariohuanuco.pe/politica/inician-estudios-para-delimitar-el-humedal-de-huachog-y-destrabar-proyecto-de-la-ptar/ (intento 3/4): HTTPSConnectionPool(host='tudiariohuanuco.pe', port=443): Max retries exceeded with url: /politica/inician-estudios-para-delimitar-el-humedal-de-huachog-y-destrabar-proyecto-de-la-ptar/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)')))
# 2025-04-21 15:25:02,948 - lib.html_scraper - INFO - Reintentando https://tudiariohuanuco.pe/politica/inician-estudios-para-delimitar-el-humedal-de-huachog-y-destrabar-proyecto-de-la-ptar/ en 10 segundos... (intento 4/4)
# 2025-04-21 15:25:02,947 - lib.html_scraper - WARNING - Error de red scrapeando https://tudiariohuanuco.pe/actualidad/seda-huanuco-detecta-manipulacion-y-alteracion-de-medidores-de-agua/ (intento 3/4): HTTPSConnectionPool(host='tudiariohuanuco.pe', port=443): Max retries exceeded with url: /actualidad/seda-huanuco-detecta-manipulacion-y-alteracion-de-medidores-de-agua/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)')))
# 2025-04-21 15:25:02,949 - lib.html_scraper - INFO - Reintentando https://tudiariohuanuco.pe/actualidad/seda-huanuco-detecta-manipulacion-y-alteracion-de-medidores-de-agua/ en 10 segundos... (intento 4/4)
# 2025-04-21 15:25:13,186 - urllib3.connectionpool - WARNING - Retrying (Retry(total=2, connect=3, read=3, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)'))': /politica/inician-estudios-para-delimitar-el-humedal-de-huachog-y-destrabar-proyecto-de-la-ptar/
# 2025-04-21 15:25:13,186 - urllib3.connectionpool - WARNING - Retrying (Retry(total=2, connect=3, read=3, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)'))': /actualidad/seda-huanuco-detecta-manipulacion-y-alteracion-de-medidores-de-agua/
# 2025-04-21 15:25:14,454 - urllib3.connectionpool - WARNING - Retrying (Retry(total=1, connect=3, read=3, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)'))': /politica/inician-estudios-para-delimitar-el-humedal-de-huachog-y-destrabar-proyecto-de-la-ptar/
# 2025-04-21 15:25:14,467 - urllib3.connectionpool - WARNING - Retrying (Retry(total=1, connect=3, read=3, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)'))': /actualidad/seda-huanuco-detecta-manipulacion-y-alteracion-de-medidores-de-agua/
# 2025-04-21 15:25:16,637 - urllib3.connectionpool - WARNING - Retrying (Retry(total=0, connect=3, read=3, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)'))': /actualidad/seda-huanuco-detecta-manipulacion-y-alteracion-de-medidores-de-agua/
# 2025-04-21 15:25:16,677 - urllib3.connectionpool - WARNING - Retrying (Retry(total=0, connect=3, read=3, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)'))': /politica/inician-estudios-para-delimitar-el-humedal-de-huachog-y-destrabar-proyecto-de-la-ptar/
# 2025-04-21 15:25:16,766 - lib.html_scraper - WARNING - Error de red scrapeando https://tudiariohuanuco.pe/politica/inician-estudios-para-delimitar-el-humedal-de-huachog-y-destrabar-proyecto-de-la-ptar/: HTTPSConnectionPool(host='tudiariohuanuco.pe', port=443): Max retries exceeded with url: /politica/inician-estudios-para-delimitar-el-humedal-de-huachog-y-destrabar-proyecto-de-la-ptar/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)')))
# 2025-04-21 15:25:16,768 - lib.html_scraper - WARNING - Error de red scrapeando https://tudiariohuanuco.pe/actualidad/seda-huanuco-detecta-manipulacion-y-alteracion-de-medidores-de-agua/: HTTPSConnectionPool(host='tudiariohuanuco.pe', port=443): Max retries exceeded with url: /actualidad/seda-huanuco-detecta-manipulacion-y-alteracion-de-medidores-de-agua/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)')))
# 2025-04-21 15:26:06,789 - lib.facebook_processor - INFO - Procesando URL de Facebook (1): https://www.facebook.com/share/v/1DQ9Yz2rnH/
# 2025-04-21 15:26:29,049 - lib.facebook_processor - INFO - PDF guardado exitosamente: C:\Jerson\SUNASS\2025\4_April\gem\scr1403\base\09042025\09042025-1.pdf
